# %%
import planetary_computer
import numpy as np
import pandas as pd
import rioxarray
import xarray
import pystac_client

# %%
#Planetary Computer Client
catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)

# %%
#Empty Dataframe for meta data
df_dictionary = pd.DataFrame(columns = ['name','type','description','table_name'])

#Search catalog for gnatsgo table collection
search = catalog.search(
    collections=["gnatsgo-tables"]
)

# %%
#Get a list of tables
collection_tables = list(search.get_items())
df_dictionary = pd.DataFrame(columns = ['name','type','description','table_name'])

# %%
#Populate dataframe with table meta-data
for i in collection_tables:
    df_i = pd.DataFrame(i.properties["table:columns"])
    df_i["table_name"] = i.id
    df_dictionary = pd.concat([df_dictionary, df_i], ignore_index=True, sort=False)
    pd.set_option('display.max_colwidth', 1000)
    
display(df_dictionary.style.set_properties(**{'text-align': 'left'}))
df_dictionary.to_csv('dictionary.csv')
# Out:
# <style type="text/css">
# #T_a973d_row0_col0, #T_a973d_row0_col1, #T_a973d_row0_col2, #T_a973d_row0_col3, #T_a973d_row1_col0, #T_a973d_row1_col1, #T_a973d_row1_col2, #T_a973d_row1_col3, #T_a973d_row2_col0, #T_a973d_row2_col1, #T_a973d_row2_col2, #T_a973d_row2_col3, #T_a973d_row3_col0, #T_a973d_row3_col1, #T_a973d_row3_col2, #T_a973d_row3_col3, #T_a973d_row4_col0, #T_a973d_row4_col1, #T_a973d_row4_col2, #T_a973d_row4_col3, #T_a973d_row5_col0, #T_a973d_row5_col1, #T_a973d_row5_col2, #T_a973d_row5_col3, #T_a973d_row6_col0, #T_a973d_row6_col1, #T_a973d_row6_col2, #T_a973d_row6_col3, #T_a973d_row7_col0, #T_a973d_row7_col1, #T_a973d_row7_col2, #T_a973d_row7_col3, #T_a973d_row8_col0, #T_a973d_row8_col1, #T_a973d_row8_col2, #T_a973d_row8_col3, #T_a973d_row9_col0, #T_a973d_row9_col1, #T_a973d_row9_col2, #T_a973d_row9_col3, #T_a973d_row10_col0, #T_a973d_row10_col1, #T_a973d_row10_col2, #T_a973d_row10_col3, #T_a973d_row11_col0, #T_a973d_row11_col1, #T_a973d_row11_col2, #T_a973d_row11_col3, #T_a973d_row12_col0, #T_a973d_row12_col1, #T_a973d_row12_col2, #T_a973d_row12_col3, #T_a973d_row13_col0, #T_a973d_row13_col1, #T_a973d_row13_col2, #T_a973d_row13_col3, #T_a973d_row14_col0, #T_a973d_row14_col1, #T_a973d_row14_col2, #T_a973d_row14_col3, #T_a973d_row15_col0, #T_a973d_row15_col1, #T_a973d_row15_col2, #T_a973d_row15_col3, #T_a973d_row16_col0, #T_a973d_row16_col1, #T_a973d_row16_col2, #T_a973d_row16_col3, #T_a973d_row17_col0, #T_a973d_row17_col1, #T_a973d_row17_col2, #T_a973d_row17_col3, #T_a973d_row18_col0, #T_a973d_row18_col1, #T_a973d_row18_col2, #T_a973d_row18_col3, #T_a973d_row19_col0, #T_a973d_row19_col1, #T_a973d_row19_col2, #T_a973d_row19_col3, #T_a973d_row20_col0, #T_a973d_row20_col1, #T_a973d_row20_col2, #T_a973d_row20_col3, #T_a973d_row21_col0, #T_a973d_row21_col1, #T_a973d_row21_col2, #T_a973d_row21_col3, #T_a973d_row22_col0, #T_a973d_row22_col1, #T_a973d_row22_col2, #T_a973d_row22_col3, #T_a973d_row23_col0, #T_a973d_row23_col1, #T_a973d_row23_col2, #T_a973d_row23_col3, #T_a973d_row24_col0, #T_a973d_row24_col1, #T_a973d_row24_col2, #T_a973d_row24_col3, #T_a973d_row25_col0, #T_a973d_row25_col1, #T_a973d_row25_col2, #T_a973d_row25_col3, #T_a973d_row26_col0, #T_a973d_row26_col1, #T_a973d_row26_col2, #T_a973d_row26_col3, #T_a973d_row27_col0, #T_a973d_row27_col1, #T_a973d_row27_col2, #T_a973d_row27_col3, #T_a973d_row28_col0, #T_a973d_row28_col1, #T_a973d_row28_col2, #T_a973d_row28_col3, #T_a973d_row29_col0, #T_a973d_row29_col1, #T_a973d_row29_col2, #T_a973d_row29_col3, #T_a973d_row30_col0, #T_a973d_row30_col1, #T_a973d_row30_col2, #T_a973d_row30_col3, #T_a973d_row31_col0, #T_a973d_row31_col1, #T_a973d_row31_col2, #T_a973d_row31_col3, #T_a973d_row32_col0, #T_a973d_row32_col1, #T_a973d_row32_col2, #T_a973d_row32_col3, #T_a973d_row33_col0, #T_a973d_row33_col1, #T_a973d_row33_col2, #T_a973d_row33_col3, #T_a973d_row34_col0, #T_a973d_row34_col1, #T_a973d_row34_col2, #T_a973d_row34_col3, #T_a973d_row35_col0, #T_a973d_row35_col1, #T_a973d_row35_col2, #T_a973d_row35_col3, #T_a973d_row36_col0, #T_a973d_row36_col1, #T_a973d_row36_col2, #T_a973d_row36_col3, #T_a973d_row37_col0, #T_a973d_row37_col1, #T_a973d_row37_col2, #T_a973d_row37_col3, #T_a973d_row38_col0, #T_a973d_row38_col1, #T_a973d_row38_col2, #T_a973d_row38_col3, #T_a973d_row39_col0, #T_a973d_row39_col1, #T_a973d_row39_col2, #T_a973d_row39_col3, #T_a973d_row40_col0, #T_a973d_row40_col1, #T_a973d_row40_col2, #T_a973d_row40_col3, #T_a973d_row41_col0, #T_a973d_row41_col1, #T_a973d_row41_col2, #T_a973d_row41_col3, #T_a973d_row42_col0, #T_a973d_row42_col1, #T_a973d_row42_col2, #T_a973d_row42_col3, #T_a973d_row43_col0, #T_a973d_row43_col1, #T_a973d_row43_col2, #T_a973d_row43_col3, #T_a973d_row44_col0, #T_a973d_row44_col1, #T_a973d_row44_col2, #T_a973d_row44_col3, #T_a973d_row45_col0, #T_a973d_row45_col1, #T_a973d_row45_col2, #T_a973d_row45_col3, #T_a973d_row46_col0, #T_a973d_row46_col1, #T_a973d_row46_col2, #T_a973d_row46_col3, #T_a973d_row47_col0, #T_a973d_row47_col1, #T_a973d_row47_col2, #T_a973d_row47_col3, #T_a973d ...

# %%
# Out:
# <style type="text/css">
# #T_d3bf6_row0_col0, #T_d3bf6_row0_col1, #T_d3bf6_row0_col2, #T_d3bf6_row0_col3, #T_d3bf6_row1_col0, #T_d3bf6_row1_col1, #T_d3bf6_row1_col2, #T_d3bf6_row1_col3, #T_d3bf6_row2_col0, #T_d3bf6_row2_col1, #T_d3bf6_row2_col2, #T_d3bf6_row2_col3, #T_d3bf6_row3_col0, #T_d3bf6_row3_col1, #T_d3bf6_row3_col2, #T_d3bf6_row3_col3, #T_d3bf6_row4_col0, #T_d3bf6_row4_col1, #T_d3bf6_row4_col2, #T_d3bf6_row4_col3, #T_d3bf6_row5_col0, #T_d3bf6_row5_col1, #T_d3bf6_row5_col2, #T_d3bf6_row5_col3, #T_d3bf6_row6_col0, #T_d3bf6_row6_col1, #T_d3bf6_row6_col2, #T_d3bf6_row6_col3, #T_d3bf6_row7_col0, #T_d3bf6_row7_col1, #T_d3bf6_row7_col2, #T_d3bf6_row7_col3, #T_d3bf6_row8_col0, #T_d3bf6_row8_col1, #T_d3bf6_row8_col2, #T_d3bf6_row8_col3, #T_d3bf6_row9_col0, #T_d3bf6_row9_col1, #T_d3bf6_row9_col2, #T_d3bf6_row9_col3, #T_d3bf6_row10_col0, #T_d3bf6_row10_col1, #T_d3bf6_row10_col2, #T_d3bf6_row10_col3, #T_d3bf6_row11_col0, #T_d3bf6_row11_col1, #T_d3bf6_row11_col2, #T_d3bf6_row11_col3, #T_d3bf6_row12_col0, #T_d3bf6_row12_col1, #T_d3bf6_row12_col2, #T_d3bf6_row12_col3, #T_d3bf6_row13_col0, #T_d3bf6_row13_col1, #T_d3bf6_row13_col2, #T_d3bf6_row13_col3, #T_d3bf6_row14_col0, #T_d3bf6_row14_col1, #T_d3bf6_row14_col2, #T_d3bf6_row14_col3, #T_d3bf6_row15_col0, #T_d3bf6_row15_col1, #T_d3bf6_row15_col2, #T_d3bf6_row15_col3, #T_d3bf6_row16_col0, #T_d3bf6_row16_col1, #T_d3bf6_row16_col2, #T_d3bf6_row16_col3, #T_d3bf6_row17_col0, #T_d3bf6_row17_col1, #T_d3bf6_row17_col2, #T_d3bf6_row17_col3, #T_d3bf6_row18_col0, #T_d3bf6_row18_col1, #T_d3bf6_row18_col2, #T_d3bf6_row18_col3, #T_d3bf6_row19_col0, #T_d3bf6_row19_col1, #T_d3bf6_row19_col2, #T_d3bf6_row19_col3, #T_d3bf6_row20_col0, #T_d3bf6_row20_col1, #T_d3bf6_row20_col2, #T_d3bf6_row20_col3, #T_d3bf6_row21_col0, #T_d3bf6_row21_col1, #T_d3bf6_row21_col2, #T_d3bf6_row21_col3, #T_d3bf6_row22_col0, #T_d3bf6_row22_col1, #T_d3bf6_row22_col2, #T_d3bf6_row22_col3, #T_d3bf6_row23_col0, #T_d3bf6_row23_col1, #T_d3bf6_row23_col2, #T_d3bf6_row23_col3, #T_d3bf6_row24_col0, #T_d3bf6_row24_col1, #T_d3bf6_row24_col2, #T_d3bf6_row24_col3, #T_d3bf6_row25_col0, #T_d3bf6_row25_col1, #T_d3bf6_row25_col2, #T_d3bf6_row25_col3, #T_d3bf6_row26_col0, #T_d3bf6_row26_col1, #T_d3bf6_row26_col2, #T_d3bf6_row26_col3, #T_d3bf6_row27_col0, #T_d3bf6_row27_col1, #T_d3bf6_row27_col2, #T_d3bf6_row27_col3, #T_d3bf6_row28_col0, #T_d3bf6_row28_col1, #T_d3bf6_row28_col2, #T_d3bf6_row28_col3, #T_d3bf6_row29_col0, #T_d3bf6_row29_col1, #T_d3bf6_row29_col2, #T_d3bf6_row29_col3, #T_d3bf6_row30_col0, #T_d3bf6_row30_col1, #T_d3bf6_row30_col2, #T_d3bf6_row30_col3, #T_d3bf6_row31_col0, #T_d3bf6_row31_col1, #T_d3bf6_row31_col2, #T_d3bf6_row31_col3, #T_d3bf6_row32_col0, #T_d3bf6_row32_col1, #T_d3bf6_row32_col2, #T_d3bf6_row32_col3, #T_d3bf6_row33_col0, #T_d3bf6_row33_col1, #T_d3bf6_row33_col2, #T_d3bf6_row33_col3, #T_d3bf6_row34_col0, #T_d3bf6_row34_col1, #T_d3bf6_row34_col2, #T_d3bf6_row34_col3, #T_d3bf6_row35_col0, #T_d3bf6_row35_col1, #T_d3bf6_row35_col2, #T_d3bf6_row35_col3, #T_d3bf6_row36_col0, #T_d3bf6_row36_col1, #T_d3bf6_row36_col2, #T_d3bf6_row36_col3, #T_d3bf6_row37_col0, #T_d3bf6_row37_col1, #T_d3bf6_row37_col2, #T_d3bf6_row37_col3, #T_d3bf6_row38_col0, #T_d3bf6_row38_col1, #T_d3bf6_row38_col2, #T_d3bf6_row38_col3, #T_d3bf6_row39_col0, #T_d3bf6_row39_col1, #T_d3bf6_row39_col2, #T_d3bf6_row39_col3, #T_d3bf6_row40_col0, #T_d3bf6_row40_col1, #T_d3bf6_row40_col2, #T_d3bf6_row40_col3, #T_d3bf6_row41_col0, #T_d3bf6_row41_col1, #T_d3bf6_row41_col2, #T_d3bf6_row41_col3, #T_d3bf6_row42_col0, #T_d3bf6_row42_col1, #T_d3bf6_row42_col2, #T_d3bf6_row42_col3, #T_d3bf6_row43_col0, #T_d3bf6_row43_col1, #T_d3bf6_row43_col2, #T_d3bf6_row43_col3, #T_d3bf6_row44_col0, #T_d3bf6_row44_col1, #T_d3bf6_row44_col2, #T_d3bf6_row44_col3, #T_d3bf6_row45_col0, #T_d3bf6_row45_col1, #T_d3bf6_row45_col2, #T_d3bf6_row45_col3, #T_d3bf6_row46_col0, #T_d3bf6_row46_col1, #T_d3bf6_row46_col2, #T_d3bf6_row46_col3, #T_d3bf6_row47_col0, #T_d3bf6_row47_col1, #T_d3bf6_row47_col2, #T_d3bf6_row47_col3, #T_d3bf6 ...
